# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import sympy
from sympy.abc import x,y,a,b,t

# %% [markdown]
# # Question 2

# %%
expression = (2*x)/(x-3)
expression
# Out:
# 2*x/(x - 3)

# %%
x = np.arange(-10, 10, 0.001)
y = (2*x)/(x-3)
plt.ylim(-10, 10)
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Question 7

# %%
expression = x**4
expression
# Out:
# x**4

# %%
x = np.arange(-10, 10, 0.001)
y = x**4
plt.ylim(0, 10)
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### f(x) = tan(x)

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 7001)
y = [math.tan(i) for i in x]
plt.ylim(-10, 10)
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### f(x) = e^x

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100000)
y = [math.e ** i for i in x]
plt.ylim(-10, 10)
plt.plot(x, y)
plt.show()

# %%
expression = 1/t
expression
# Out:
# 1/t

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 10001)
y = [1/i for i in x]
plt.ylim(-10, 10)
plt.plot(x, y)
plt.show()
# Out:
# <ipython-input-3-97fa14accd38>:2: RuntimeWarning: divide by zero encountered in double_scalars
#   y = [1/i for i in x]

# %% [markdown]
# # Question 9

# %%
expression = 1/x**2
expression
# Out:
# x**(-2)

# %%
sympy.diff(expression,x)
# Out:
# -2/x**3

# %%
# expression = sympy.cbrt(x**2)
expression = x**(2/3)
expression
# Out:
# x**0.666666666666667

# %%
sympy.diff(expression,x)
# Out:
# 0.666666666666667*x**(-0.333333333333333)

# %% [markdown]
# # Question 10

# %%
expression = sympy.sqrt(t)*(a+b*t)
expression
# Out:
# sqrt(t)*(a + b*t)

# %%
sympy.diff(expression,t)
# Out:
# b*sqrt(t) + (a + b*t)/(2*sqrt(t))

# %% [markdown]
# # Question 12

# %%
expression = (x**2 + x - 2)/(x**3 + 6)
expression
# Out:
# (x**2 + x - 2)/(x**3 + 6)

# %%
sympy.diff(expression,x)
# Out:
# -3*x**2*(x**2 + x - 2)/(x**3 + 6)**2 + (2*x + 1)/(x**3 + 6)

# %% [markdown]
# # Question 14

# %%
expresion = sympy.Eq(x**2+y**3,4)
expresion
# Out:
# Eq(x**2 + y**3, 4)

# %%
expresion = sympy.Eq(x**2+y**3-4,0)
expresion
# Out:
# Eq(x**2 + y**3 - 4, 0)

# %%
expresion = x**2 + y**3 - 4
sympy.idiff(expresion,y,x,n=1)
# Out:
# -2*x/(3*y**2)
